# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Create a dummy dataset
x = np.linspace(0, 10, 100)
y = np.sin(x) + 0.1 * np.random.randn(100)

# Plot the dataset
plt.plot(x, y, 'o')
plt.show()

# %%
# Create cosine dataset
x = np.linspace(0, 10, 100)
y = np.cos(x) + 0.1 * np.random.randn(100)

# Plot the dataset
plt.plot(x, y, 'o')
plt.show()

# %%
# Do it for tangent now
x = np.linspace(0, 10, 100)
y = np.tan(x) + 0.1 * np.random.randn(100)

# Plot the dataset
plt.plot(x, y, 'o')
plt.show()
